# %% [markdown]
# # Entraînement autoencodeur (Colab GPU)
#
# Notebook d'entraînement GPU. **À lancer sur Google Colab (runtime GPU).**
#
# Responsabilités : clone, install, Drive optionnel, téléchargement des
# données, entraînement, sauvegarde checkpoints + métriques, reprise après
# interruption, export vers Drive, puis affichage de la commande git à
# exécuter localement pour rapatrier les artefacts.

# %%
# --- Setup Colab (à exécuter en premier) ---
# 1) Cloner le dépôt
# !git clone https://github.com/OWNER/cross-domain-visual-anomaly-detection.git
# %cd cross-domain-visual-anomaly-detection
# 2) Installer les dépendances
# !pip install -e .
# 3) (Optionnel) monter Google Drive pour checkpoints/datasets
# from google.colab import drive; drive.mount('/content/drive')
# 4) Vérifier le GPU
# import torch; print('CUDA:', torch.cuda.is_available())

# %% [markdown]
# ## Entraînement
#
# À compléter en Phase 2 / 4.

# %%
# profile: colab_gpu
# À compléter
